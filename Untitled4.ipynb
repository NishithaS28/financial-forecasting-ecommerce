# %% [markdown]
# <a href="https://colab.research.google.com/github/NishithaS28/financial-forecasting-ecommerce/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file (uploaded in the Colab file system)
file_path = '/content/symbols_valid_meta.csv'  # Path to the uploaded file
data = pd.read_csv(file_path)

# Filter for AAPL (Apple's stock symbol)
aapl_data = data[data['Symbol'] == 'AAPL']

# Save the filtered data as AAPL_intraday.csv
aapl_data.to_csv('AAPL_intraday.csv', index=False)

# Check if the data is filtered correctly
aapl_data.head()
# Out:
#    Nasdaq Traded Symbol              Security Name Listing Exchange  \
# 12             Y   AAPL  Apple Inc. - Common Stock                Q
#
#    Market Category ETF  Round Lot Size Test Issue Financial Status CQS Symbol  \
# 12               Q   N           100.0          N                N        NaN
#
#    NASDAQ Symbol NextShares
# 12          AAPL          N

# %%
# Save the filtered data as AAPL_intraday.csv
aapl_data.to_csv('AAPL_intraday.csv', index=False)
print("AAPL data saved as AAPL_intraday.csv")
# Out:
# AAPL data saved as AAPL_intraday.csv

# %%
from google.colab import files
files.download('AAPL_intraday.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the stock data (AAPL_intraday.csv)
data = pd.read_csv('/content/AAPL.csv', index_col='date', parse_dates=True)

# Calculate Simple Moving Averages (SMA)
data['SMA_20'] = data['4. close'].rolling(window=20).mean()
data['SMA_50'] = data['4. close'].rolling(window=50).mean()

# Generate buy/sell signals
data['Signal'] = 0
data['Signal'][20:] = np.where(data['SMA_20'][20:] > data['SMA_50'][20:], 1, 0)
data['Position'] = data['Signal'].diff()

# Save signals
data.to_csv('../data/AAPL_signals.csv')
print("Trade signals saved as AAPL_signals.csv")

# Plot the signals
plt.figure(figsize=(10,6))
plt.plot(data['4. close'], label='Stock Price')
plt.plot(data['SMA_20'], label='20-day SMA')
plt.plot(data['SMA_50'], label='50-day SMA')
plt.scatter(data.index, data['Position'] == 1, color='green', label='Buy Signal', marker='^', alpha=1)
plt.scatter(data.index, data['Position'] == -1, color='red', label='Sell Signal', marker='v', alpha=1)
plt.title('AAPL Stock Price and Trade Signals')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f6e0b7e6f47b> in <cell line: 6>()
#       4
#       5 # Load the stock data (AAPL_intraday.csv)
# ----> 6 data = pd.read_csv('/content/AAPL.csv', index_col='date', parse_dates=True)
#       7
#       8 # Calculate Simple Moving Averages (SMA)
#
# ...

# %%
data = pd.read_csv('/content/AAPL.csv')
print(data.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Symbol',
#        'YTD Gains'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the stock data (AAPL.csv)
data = pd.read_csv('/content/AAPL.csv', index_col='Date', parse_dates=True)

# Calculate Simple Moving Averages (SMA)
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['SMA_50'] = data['Close'].rolling(window=50).mean()

# Generate buy/sell signals
data['Signal'] = 0
data['Signal'][20:] = np.where(data['SMA_20'][20:] > data['SMA_50'][20:], 1, 0)
data['Position'] = data['Signal'].diff()

# Save signals
data.to_csv('/content/AAPL_signals.csv')
print("Trade signals saved as AAPL_signals.csv")

# Plot the signals
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label='Stock Price')
plt.plot(data['SMA_20'], label='20-day SMA')
plt.plot(data['SMA_50'], label='50-day SMA')
plt.scatter(data.index, data['Position'] == 1, color='green', label='Buy Signal', marker='^', alpha=1)
plt.scatter(data.index, data['Position'] == -1, color='red', label='Sell Signal', marker='v', alpha=1)
plt.title('AAPL Stock Price and Trade Signals')
plt.legend()
plt.show()
# Out:
# <ipython-input-11-3d126a25fa70>:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['Signal'][20:] = np.where(data['SMA_20'][20:] > data['SMA_50'][20:], 1, 0)
# ...

# %%
# Plot the signals
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label='Stock Price')
plt.plot(data['SMA_20'], label='20-day SMA')
plt.plot(data['SMA_50'], label='50-day SMA')

# Adjust buy/sell markers to be at the same Y level as the stock price
plt.scatter(data.index[data['Position'] == 1], data['Close'][data['Position'] == 1],
            color='green', label='Buy Signal', marker='^', alpha=1)
plt.scatter(data.index[data['Position'] == -1], data['Close'][data['Position'] == -1],
            color='red', label='Sell Signal', marker='v', alpha=1)

plt.title('AAPL Stock Price and Trade Signals')
plt.legend()
plt.show()

# %%
# To verify the saved signals:
signals = pd.read_csv('/content/AAPL_signals.csv')
print(signals.head())
# Out:
#          Date      Open      High       Low     Close     Volume Symbol  \
# 0  2002-12-31  0.250000  0.256429  0.249107  0.255893  200726400   AAPL
# 1  2003-01-02  0.256429  0.266429  0.256250  0.264286  181428800   AAPL
# 2  2003-01-03  0.264286  0.266607  0.260536  0.266071  147453600   AAPL
# 3  2003-01-06  0.268393  0.274643  0.265714  0.266071  390532800   AAPL
# 4  2003-01-07  0.264107  0.267857  0.258393  0.265179  342344800   AAPL
#
#    YTD Gains  SMA_20  SMA_50  Signal  Position
# 0   0.000000     NaN     NaN       0       NaN
# 1   0.032799     NaN     NaN       0       0.0
# 2   0.039774     NaN     NaN       0       0.0
# 3   0.039774     NaN     NaN       0       0.0
# 4   0.036289     NaN     NaN       0       0.0

# %%
print(signals.iloc[50:60])
# Out:
#           Date      Open      High       Low     Close     Volume Symbol  \
# 50  2003-03-14  0.262143  0.268036  0.261429  0.263929  153098400   AAPL
# 51  2003-03-17  0.265893  0.269107  0.262679  0.268036  399912800   AAPL
# 52  2003-03-18  0.267857  0.269464  0.264643  0.267857  229980800   AAPL
# 53  2003-03-19  0.269107  0.270536  0.264107  0.266964  141316000   AAPL
# 54  2003-03-20  0.266607  0.267679  0.260714  0.266250  163178400   AAPL
# 55  2003-03-21  0.269464  0.270536  0.264643  0.267857  297948000   AAPL
# 56  2003-03-24  0.261964  0.264286  0.256250  0.256607  161100800   AAPL
# 57  2003-03-25  0.257321  0.264821  0.256607  0.259821  167697600   AAPL
# 58  2003-03-26  0.259821  0.260000  0.255357  0.257321  178343200   AAPL
# 59  2003-03-27  0.255714  0.262500  0.255714  0.258750  122393600   AAPL
#
#     YTD Gains    SMA_20    SMA_50  Signal  Position
# 50   0.031404  0.262437  0.259939       1       0.0
# 51   0.047453  0.262741  0.260014       1       0.0
# ...

# %%
print(signals.iloc[50:100])
# Out:
#           Date      Open      High       Low     Close      Volume Symbol  \
# 50  2003-03-14  0.262143  0.268036  0.261429  0.263929   153098400   AAPL
# 51  2003-03-17  0.265893  0.269107  0.262679  0.268036   399912800   AAPL
# 52  2003-03-18  0.267857  0.269464  0.264643  0.267857   229980800   AAPL
# 53  2003-03-19  0.269107  0.270536  0.264107  0.266964   141316000   AAPL
# 54  2003-03-20  0.266607  0.267679  0.260714  0.266250   163178400   AAPL
# 55  2003-03-21  0.269464  0.270536  0.264643  0.267857   297948000   AAPL
# 56  2003-03-24  0.261964  0.264286  0.256250  0.256607   161100800   AAPL
# 57  2003-03-25  0.257321  0.264821  0.256607  0.259821   167697600   AAPL
# 58  2003-03-26  0.259821  0.260000  0.255357  0.257321   178343200   AAPL
# 59  2003-03-27  0.255714  0.262500  0.255714  0.258750   122393600   AAPL
# 60  2003-03-28  0.257143  0.261071  0.256607  0.260179   145303200   AAPL
# 61  2003-03-31  0.255893  0.259464  0.250714  0.252500   256659200   AAPL
# ...

# %%
# Calculate daily returns
data['Daily_Return'] = data['Close'].pct_change()

# Calculate strategy returns based on the position
data['Strategy_Return'] = data['Daily_Return'] * data['Position'].shift(1)  # Use shift to align with previous day's position

# Calculate cumulative returns for both buy/hold and strategy
data['Cumulative_Strategy_Return'] = (1 + data['Strategy_Return']).cumprod() - 1
data['Cumulative_Market_Return'] = (1 + data['Daily_Return']).cumprod() - 1

# Plot the cumulative returns
plt.figure(figsize=(10,6))
plt.plot(data['Cumulative_Strategy_Return'], label='Strategy Returns')
plt.plot(data['Cumulative_Market_Return'], label='Market Returns (Buy and Hold)')
plt.title('Strategy vs Market Returns')
plt.legend()
plt.show()

# %%
# Generate buy/sell signals using iloc for positional indexing
data.iloc[10:, data.columns.get_loc('Signal')] = np.where(data.iloc[10:]['SMA_10'] > data.iloc[10:]['SMA_30'], 1, 0)

# Calculate the Position
data['Position'] = data['Signal'].diff()

# %%
print(data.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Symbol', 'YTD Gains',
#        'SMA_20', 'SMA_50', 'Signal', 'Position', 'Daily_Return',
#        'Strategy_Return', 'Cumulative_Strategy_Return',
#        'Cumulative_Market_Return', 'SMA_10', 'SMA_30'],
#       dtype='object')

# %%
# Print the head or tail without 'Date'
print(data[['Close', 'SMA_10', 'SMA_30', 'Signal', 'Position']].tail(20))
# Out:
#                  Close      SMA_10      SMA_30  Signal  Position
# Date
# 2023-05-12  172.570007  171.009000  167.028667       1       0.0
# 2023-05-15  172.070007  171.257001  167.267667       1       0.0
# 2023-05-16  172.070007  171.610002  167.464334       1       0.0
# 2023-05-17  172.690002  172.134003  167.699667       1       0.0
# 2023-05-18  175.050003  173.060004  168.076001       1       0.0
# 2023-05-19  175.160004  173.219003  168.426001       1       0.0
# 2023-05-22  174.199997  173.289003  168.831668       1       0.0
# 2023-05-23  171.559998  173.268002  169.190334       1       0.0
# 2023-05-24  171.839996  173.096002  169.581667       1       0.0
# 2023-05-25  172.990005  173.020003  169.829334       1       0.0
# 2023-05-26  175.429993  173.306001  170.170000       1       0.0
# 2023-05-30  177.300003  173.829001  170.572334       1       0.0
# 2023-05-31  177.250000  174.347000  170.931667       1       0.0
# ...

# %%
# Filter data for buy signals (where Position is 1)
buy_signals = data[data['Position'] == 1]
# Filter data for sell signals (where Position is -1)
sell_signals = data[data['Position'] == -1]

plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Close Price', alpha=0.5)
plt.plot(data.index, data['SMA_10'], label='SMA 10')
plt.plot(data.index, data['SMA_30'], label='SMA 30')

# Buy signals (where Position is 1)
plt.scatter(buy_signals.index, buy_signals['Close'], label='Buy Signal', marker='^', color='green', alpha=1)

# Sell signals (where Position is -1)
plt.scatter(sell_signals.index, sell_signals['Close'], label='Sell Signal', marker='v', color='red', alpha=1)

plt.title('Stock Price and Buy/Sell Signals')
plt.legend()
plt.show()
